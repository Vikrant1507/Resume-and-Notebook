# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
import seaborn as sns

# %%
pd.set_option('display.max_columns',100)
df=pd.read_csv(r'C:\Users\samee\Downloads\ObesityDataSet.csv')
df
# Out:
#       Gender        Age    Height      Weight family_history_with_overweight  \
# 0     Female  21.000000  1.620000   64.000000                            yes
# 1     Female  21.000000  1.520000   56.000000                            yes
# 2       Male  23.000000  1.800000   77.000000                            yes
# 3       Male  27.000000  1.800000   87.000000                             no
# 4       Male  22.000000  1.780000   89.800000                             no
# ...      ...        ...       ...         ...                            ...
# 2106  Female  20.976842  1.710730  131.408528                            yes
# 2107  Female  21.982942  1.748584  133.742943                            yes
# 2108  Female  22.524036  1.752206  133.689352                            yes
# 2109  Female  24.361936  1.739450  133.346641                            yes
# 2110  Female  23.664709  1.738836  133.472641                            yes
#
# ...

# %%
df['Age'] = df['Age'].round()
df
# Out:
#       Gender   Age    Height      Weight family_history_with_overweight FAVC  \
# 0     Female  21.0  1.620000   64.000000                            yes   no
# 1     Female  21.0  1.520000   56.000000                            yes   no
# 2       Male  23.0  1.800000   77.000000                            yes   no
# 3       Male  27.0  1.800000   87.000000                             no   no
# 4       Male  22.0  1.780000   89.800000                             no   no
# ...      ...   ...       ...         ...                            ...  ...
# 2106  Female  21.0  1.710730  131.408528                            yes  yes
# 2107  Female  22.0  1.748584  133.742943                            yes  yes
# 2108  Female  23.0  1.752206  133.689352                            yes  yes
# 2109  Female  24.0  1.739450  133.346641                            yes  yes
# 2110  Female  24.0  1.738836  133.472641                            yes  yes
#
# ...

# %%
df.shape
# Out:
# (2111, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2111 entries, 0 to 2110
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Gender                          2111 non-null   object
#  1   Age                             2111 non-null   float64
#  2   Height                          2111 non-null   float64
#  3   Weight                          2111 non-null   float64
#  4   family_history_with_overweight  2111 non-null   object
#  5   FAVC                            2111 non-null   object
#  6   FCVC                            2111 non-null   float64
#  7   NCP                             2111 non-null   float64
#  8   CAEC                            2111 non-null   object
#  9   SMOKE                           2111 non-null   object
#  10  CH2O                            2111 non-null   float64
#  11  SCC                             2111 non-null   object
# ...

# %%
df.describe()
# Out:
#                Age       Height       Weight         FCVC          NCP  \
# count  2111.000000  2111.000000  2111.000000  2111.000000  2111.000000
# mean     24.315964     1.701677    86.586058     2.419043     2.685628
# std       6.357078     0.093305    26.191172     0.533927     0.778039
# min      14.000000     1.450000    39.000000     1.000000     1.000000
# 25%      20.000000     1.630000    65.473343     2.000000     2.658738
# 50%      23.000000     1.700499    83.000000     2.385502     3.000000
# 75%      26.000000     1.768464   107.430682     3.000000     3.000000
# max      61.000000     1.980000   173.000000     3.000000     4.000000
#
#               CH2O          FAF          TUE
# count  2111.000000  2111.000000  2111.000000
# mean      2.008011     1.010298     0.657866
# std       0.612953     0.850592     0.608927
# min       1.000000     0.000000     0.000000
# 25%       1.584812     0.124505     0.000000
# 50%       2.000000     1.000000     0.625350
# ...

# %%
df.isnull().sum()
# Out:
# Gender                            0
# Age                               0
# Height                            0
# Weight                            0
# family_history_with_overweight    0
# FAVC                              0
# FCVC                              0
# NCP                               0
# CAEC                              0
# SMOKE                             0
# CH2O                              0
# SCC                               0
# FAF                               0
# TUE                               0
# CALC                              0
# MTRANS                            0
# NObeyesdad                        0
# dtype: int64

# %%
cat_col=[]
for col in df.columns:
    if df[col].dtype=='object':
        cat_col.append(col)
print('Categorical Coloumns',cat_col)
# Out:
# Categorical Coloumns ['Gender', 'family_history_with_overweight', 'FAVC', 'CAEC', 'SMOKE', 'SCC', 'CALC', 'MTRANS', 'NObeyesdad']

# %%
num_col=[]
for col in df.columns:
    if df[col].dtype!='object':
        num_col.append(col)
print('Numerical Coloumns',num_col)
# Out:
# Numerical Coloumns ['Age', 'Height', 'Weight', 'FCVC', 'NCP', 'CH2O', 'FAF', 'TUE']

# %%
duplicates = df[df.duplicated()]
duplicates
# Out:
#      Gender   Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 98   Female  21.0    1.52    42.0                             no   no   3.0
# 106  Female  25.0    1.57    55.0                             no  yes   2.0
# 174    Male  21.0    1.62    70.0                             no  yes   2.0
# 179    Male  21.0    1.62    70.0                             no  yes   2.0
# 184    Male  21.0    1.62    70.0                             no  yes   2.0
# 209  Female  22.0    1.69    65.0                            yes  yes   2.0
# 309  Female  16.0    1.66    58.0                             no   no   2.0
# 460  Female  18.0    1.62    55.0                            yes  yes   2.0
# 467    Male  22.0    1.74    75.0                            yes  yes   3.0
# 496    Male  18.0    1.72    53.0                            yes  yes   2.0
# 527  Female  21.0    1.52    42.0                             no  yes   3.0
# ...

# %%
df.duplicated().sum()
# Out:
# 24

# %%
df.drop_duplicates(inplace=True)

# Print the cleaned DataFrame
print("Number of remaining data points after dropping duplicates:", len(df))
df
# Out:
# Number of remaining data points after dropping duplicates: 2087
#       Gender   Age    Height      Weight family_history_with_overweight FAVC  \
# 0     Female  21.0  1.620000   64.000000                            yes   no
# 1     Female  21.0  1.520000   56.000000                            yes   no
# 2       Male  23.0  1.800000   77.000000                            yes   no
# 3       Male  27.0  1.800000   87.000000                             no   no
# 4       Male  22.0  1.780000   89.800000                             no   no
# ...      ...   ...       ...         ...                            ...  ...
# 2106  Female  21.0  1.710730  131.408528                            yes  yes
# 2107  Female  22.0  1.748584  133.742943                            yes  yes
# 2108  Female  23.0  1.752206  133.689352                            yes  yes
# 2109  Female  24.0  1.739450  133.346641                            yes  yes
# ...

# %%
df['NObeyesdad'].value_counts()
# Out:
# Obesity_Type_I         351
# Obesity_Type_III       324
# Obesity_Type_II        297
# Overweight_Level_II    290
# Normal_Weight          282
# Overweight_Level_I     276
# Insufficient_Weight    267
# Name: NObeyesdad, dtype: int64

# %%
plt.hist('Age',data=df)
# Out:
# (array([300., 916., 452., 174., 115., 104.,  14.,   4.,   7.,   1.]),
#  array([14. , 18.7, 23.4, 28.1, 32.8, 37.5, 42.2, 46.9, 51.6, 56.3, 61. ]),
#  <BarContainer object of 10 artists>)

# %%
df.boxplot(column='Age')
# Out:
# <AxesSubplot:>

# %%
Q1 = df['Age'].quantile(0.25)
Q3 = df['Age'].quantile(0.75)
IQR = Q3 - Q1
print('IQR',IQR)

# Calculating the lower and upper bounds
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
 
print('Lower Bound :',round(lower_bound))
print('Upper Bound :',round(upper_bound))
 
# Drop the outliers
df = df[(df['Age'] >= lower_bound) 
                & (df['Age'] <= upper_bound)]
# Out:
# IQR 6.0
# Lower Bound : 11
# Upper Bound : 35

# %% [markdown]
# Percentiles: Percentiles are a type of quantile that divide a dataset into 100 equal parts. For example, the 25th percentile (also known as the first quartile) represents the value below which 25% of the observations in the dataset fall.
#
# Quartiles: Quartiles are a type of quantile that divide a dataset into four equal parts. The first quartile (Q1) represents the 25th percentile, the second quartile (Q2) represents the median (50th percentile), and the third quartile (Q3) represents the 75th percentile.

# %%
df.boxplot(column='Age')
# Out:
# <AxesSubplot:>

# %%
plt.hist('Height',data=df)
# Out:
# (array([ 20.,  84., 184., 380., 364., 387., 291., 166.,  43.,   8.]),
#  array([1.45 , 1.503, 1.556, 1.609, 1.662, 1.715, 1.768, 1.821, 1.874,
#         1.927, 1.98 ]),
#  <BarContainer object of 10 artists>)

# %%
df.boxplot(column='Height')
# Out:
# <AxesSubplot:>

# %%
Q1=df['Height'].quantile(0.25)
Q3=df['Height'].quantile(0.75)
IQR = Q3-Q1
print('IQR',IQR)

# Calculating the lower and upper bounds
lower_bound = Q1-1.5*IQR
upper_bound = Q3+1.5*IQR

print('lower_bound',round(lower_bound))
print('upper_bound',round(upper_bound))

#drop the outliers
df = df[(df['Height'] >= lower_bound) & (df['Height'] <= upper_bound)]
# Out:
# IQR 0.13663400000000014
# lower_bound 1
# upper_bound 2

# %%
df.boxplot(column='Height')
# Out:
# <AxesSubplot:>

# %%
#Numerical Coloumns ['Age', 'Height', 'Weight', 'FCVC', 'NCP', 'CH2O', 'FAF', 'TUE']

# %%
plt.hist('Weight',data=df)
# Out:
# (array([237., 265., 289., 359., 260., 263., 154.,  74.,  21.,   4.]),
#  array([ 39. ,  52.4,  65.8,  79.2,  92.6, 106. , 119.4, 132.8, 146.2,
#         159.6, 173. ]),
#  <BarContainer object of 10 artists>)

# %%
df.boxplot(column='Weight')
# Out:
# <AxesSubplot:>

# %%
Q1 = df['Weight'].quantile(0.25)
Q3 = df['Weight'].quantile(0.75)
IQR = Q3 - Q1
print('IQR',IQR)

# Calculating the lower and upper bounds
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
 
print('Lower Bound :',round(lower_bound))
print('Upper Bound :',round(upper_bound))
 
# Drop the outliers
df = df[(df['Weight'] >= lower_bound) 
                & (df['Weight'] <= upper_bound)]
# Out:
# IQR 43.6920985
# Lower Bound : -1
# Upper Bound : 174

# %%
df.boxplot(column='Weight')
# Out:
# <AxesSubplot:>

# %%
plt.hist('FCVC',data=df)
# Out:
# (array([ 60.,  28.,  32.,  30.,  52., 642., 102.,  83., 118., 779.]),
#  array([1. , 1.2, 1.4, 1.6, 1.8, 2. , 2.2, 2.4, 2.6, 2.8, 3. ]),
#  <BarContainer object of 10 artists>)

# %%
df.boxplot(column='FCVC')
# Out:
# <AxesSubplot:>

# %%
plt.hist('NCP',data=df)
# Out:
# (array([ 239.,   38.,   50.,   54.,   48.,   76., 1219.,   48.,   42.,
#          112.]),
#  array([1. , 1.3, 1.6, 1.9, 2.2, 2.5, 2.8, 3.1, 3.4, 3.7, 4. ]),
#  <BarContainer object of 10 artists>)

# %%
df.boxplot(column='NCP')
# Out:
# <AxesSubplot:>

# %%
'''Q1 = df['NCP'].quantile(0.25)
Q3 = df['NCP'].quantile(0.75)
IQR = Q3 - Q1
print('IQR',IQR)

# Calculating the lower and upper bounds
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
 
print('Lower Bound :',round(lower_bound))
print('Upper Bound :',round(upper_bound))
 
# Drop the outliers
df = df[(df['NCP'] >= lower_bound) 
                & (df['NCP'] <= upper_bound)]'''
# Out:
# "Q1 = df['NCP'].quantile(0.25)\nQ3 = df['NCP'].quantile(0.75)\nIQR = Q3 - Q1\nprint('IQR',IQR)\n\n# Calculating the lower and upper bounds\nlower_bound = Q1 - 1.5 * IQR\nupper_bound = Q3 + 1.5 * IQR\n \nprint('Lower Bound :',round(lower_bound))\nprint('Upper Bound :',round(upper_bound))\n \n# Drop the outliers\ndf = df[(df['NCP'] >= lower_bound) \n                & (df['NCP'] <= upper_bound)]"

# %%
#df.boxplot(column='NCP')

# %%
plt.hist('CH2O',data=df)
# Out:
# (array([300.,  96.,  78.,  94., 108., 606., 113., 121., 154., 256.]),
#  array([1. , 1.2, 1.4, 1.6, 1.8, 2. , 2.2, 2.4, 2.6, 2.8, 3. ]),
#  <BarContainer object of 10 artists>)

# %%
df.boxplot(column='CH2O')
# Out:
# <AxesSubplot:>

# %%
plt.hist('FAF',data=df)
# Out:
# (array([564., 120., 140., 385., 142., 129., 292.,  35.,  26.,  93.]),
#  array([0. , 0.3, 0.6, 0.9, 1.2, 1.5, 1.8, 2.1, 2.4, 2.7, 3. ]),
#  <BarContainer object of 10 artists>)

# %%
df.boxplot(column='FAF')
# Out:
# <AxesSubplot:>

# %%
plt.hist('TUE',data=df)
# Out:
# (array([597., 126., 160., 173., 192., 337.,  68.,  65.,  55., 153.]),
#  array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2, 1.4, 1.6, 1.8, 2. ]),
#  <BarContainer object of 10 artists>)

# %%
df.boxplot(column='TUE')
# Out:
# <AxesSubplot:>

# %%
sns.scatterplot(x=df['Age'],y=df['Height'],hue=df['NObeyesdad'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Height'>

# %%
sns.scatterplot(x=df['Age'],y=df['Weight'],hue=df['NObeyesdad'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Weight'>

# %%
sns.scatterplot(x=df['Height'],y=df['Weight'],hue=df['NObeyesdad'])
# Out:
# <AxesSubplot:xlabel='Height', ylabel='Weight'>

# %% [markdown]
# ## Visualizing categorical Variable

# %%
#['Gender', 'family_history_with_overweight', 'FAVC', 'CAEC', 'SMOKE', 'SCC', 'CALC', 'MTRANS', 'NObeyesdad']

# %%
df['MTRANS'].unique()
# Out:
# array(['Public_Transportation', 'Walking', 'Automobile', 'Motorbike',
#        'Bike'], dtype=object)

# %%
plt.figure(figsize=(5,5))
plt.pie(df['Gender'].value_counts(),startangle=90,autopct='%.2f',labels=['Female', 'Male'],shadow=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
plt.pie(df['family_history_with_overweight'].value_counts(),startangle=90,autopct='%.2f',labels=['yes', 'no'],shadow=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
plt.pie(df['FAVC'].value_counts(),startangle=90,autopct='%.2f',labels=['no', 'yes'],shadow=True)
plt.show()

# %%
plt.figure(figsize=(50,10))
plt.pie(df['CAEC'].value_counts(),startangle=90,autopct='%.2f',labels=['Sometimes', 'Frequently', 'Always', 'no'],shadow=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
plt.pie(df['SMOKE'].value_counts(),startangle=90,autopct='%.2f',labels=['no', 'yes'],shadow=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
plt.pie(df['CALC'].value_counts(),startangle=90,autopct='%.2f',labels=['no', 'Sometimes', 'Frequently', 'Always'],shadow=True)
plt.show()

# %%
plt.figure(figsize=(5,40))
plt.pie(df['MTRANS'].value_counts(),startangle=90,autopct='%.2f',labels=['Public_Transportation', 'Walking', 'Automobile', 'Motorbike','Bike'],shadow=True)
plt.show()

# %%
plt.figure(figsize=(13, 5))
sns.countplot(data=df, x='NObeyesdad')
plt.legend(loc='best')
plt.title("NObeyesdad categories and count")
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# ## BIVARIATE ANALYSIS

# %%
plt.figure(figsize=(10,5))
sns.countplot(data=df,x='Gender',hue='NObeyesdad')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# 'best': Automatically choose the location that overlaps the fewest data points and does not obscure the plot. Matplotlib tries to find the best position for the legend by minimizing the overlap with other elements in the plot.

# %% [markdown]
# We noticed that men tend to have much less Obesity Type III, while women seem to have less Obesity Type II. There might be different reasons for this.

# %%
plt.figure(figsize=(10,5))
sns.countplot(data=df,x='FAVC',hue='NObeyesdad')
plt.legend(loc='best')
plt.title("Frequent Consumption of High Caloric Food")
plt.show()

# %% [markdown]
# We can see that individuals with frequent consumption of high caloric food are more likely to be obese, which makes sense.

# %%
plt.figure(figsize=(10, 5))
sns.countplot(data=df, x='CAEC', hue='NObeyesdad')
plt.legend(loc='best')
plt.title("Consumption of Food Between Meals")
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.countplot(data=df, x='SMOKE', hue='NObeyesdad')
plt.legend(loc='best')
plt.title("Smoking")
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.countplot(data=df, x='SCC', hue='NObeyesdad')
plt.legend(loc='best')
plt.title("Calories Consumption Monitoring")
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.countplot(data=df, x='CALC', hue='NObeyesdad')
plt.legend(loc='best')
plt.title("Consumption of Alcohol")
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.countplot(data=df, x='MTRANS', hue='NObeyesdad')
plt.legend(loc='best')
plt.title("Transportation Used")
plt.show()

# %% [markdown]
# It is visible that there are alot of class imbalances in the categorical features, we will try to deal with it later on.

# %%
print('Categorical Coloumns',cat_col)
# Out:
# Categorical Coloumns ['Gender', 'family_history_with_overweight', 'FAVC', 'CAEC', 'SMOKE', 'SCC', 'CALC', 'MTRANS', 'NObeyesdad']

# %%
#category vs category
pd.crosstab(df['Gender'],df['family_history_with_overweight'],margins=True,values=df['NObeyesdad'],aggfunc=pd.Series.count)
# Out:
# family_history_with_overweight   no   yes   All
# Gender
# Female                          219   720   939
# Male                            133   854   987
# All                             352  1574  1926

# %% [markdown]
# df['family_history_with_overweight'] and df['Gender']: These are the two columns of the DataFrame df that you want to cross-tabulate.
#
# margins=True: This parameter specifies whether to compute row and column margins (subtotals). Setting it to True will include row and column totals in the resulting cross-tabulation.
#
# values=df['NObeyesdad']: This parameter specifies the values to aggregate according to the cross-tabulation. In your case, you're using the 'NObeyesdad' column as the values to count.
#
# If you want to aggregate the 'NObeyesdad' values within each group defined by the cross-tabulation of 'family_history_with_overweight' and 'Gender', you need to specify an appropriate aggregation function that can aggregate these values. Some common aggregation functions include np.sum, np.mean, np.median, np.max, np.min, etc.
#
# If the 'NObeyesdad' column contains numerical data, you can use one of these aggregation functions. However, if the 'NObeyesdad' column contains categorical data or if you need to apply a custom aggregation function, you may need to preprocess the data or define a custom aggregation function accordingly.

# %%
pd.crosstab(df['Gender'],df['FAVC'],margins=True,values=df['NObeyesdad'],aggfunc=pd.Series.count)
# Out:
# FAVC     no   yes   All
# Gender
# Female  134   805   939
# Male     94   893   987
# All     228  1698  1926

# %%
pd.crosstab(df['CAEC'],df['FAVC'],margins=True,values=df['NObeyesdad'],aggfunc=pd.Series.count)
# Out:
# FAVC         no   yes   All
# CAEC
# Always       12    37    49
# Frequently   63   163   226
# Sometimes   144  1470  1614
# no            9    28    37
# All         228  1698  1926

# %%
pd.crosstab(df['Gender'],df['SMOKE'],margins=True,values=df['NObeyesdad'],aggfunc=pd.Series.count)
# Out:
# SMOKE     no  yes   All
# Gender
# Female   927   12   939
# Male     960   27   987
# All     1887   39  1926

# %%
#to checck cat vs cat bivariate analysis
corr = df.corr()

# Create a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt='.2f', annot_kws={"size": 12})
plt.title('Correlation Heatmap', fontsize=16)
plt.show()

# %% [markdown]
# ## Data scaling and Transformation

# %%
from sklearn.preprocessing import LabelEncoder
# Creating a LabelEncoder instance
label_encoder = LabelEncoder()

# Fit and transform the 'Gender' column
df['Gender'] = label_encoder.fit_transform(df['Gender'])

# Display the modified DataFrame
df.head()

#0 for female and 1 for male
# Out:
#    Gender   Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 0       0  21.0    1.62    64.0                            yes   no   2.0
# 1       0  21.0    1.52    56.0                            yes   no   3.0
# 2       1  23.0    1.80    77.0                            yes   no   2.0
# 3       1  27.0    1.80    87.0                             no   no   3.0
# 4       1  22.0    1.78    89.8                             no   no   2.0
#
#    NCP       CAEC SMOKE  CH2O  SCC  FAF  TUE        CALC  \
# 0  3.0  Sometimes    no   2.0   no  0.0  1.0          no
# 1  3.0  Sometimes   yes   3.0  yes  3.0  0.0   Sometimes
# 2  3.0  Sometimes    no   2.0   no  2.0  1.0  Frequently
# 3  3.0  Sometimes    no   2.0   no  2.0  0.0  Frequently
# 4  1.0  Sometimes    no   2.0   no  0.0  0.0   Sometimes
#
#                   MTRANS           NObeyesdad
# 0  Public_Transportation        Normal_Weight
# 1  Public_Transportation        Normal_Weight
# ...

# %%
df['Gender'].unique()
# Out:
# array([0, 1])

# %%
label_encoder=LabelEncoder()
# Fit and transform the 'Gender' column
df['family_history_with_overweight']=label_encoder.fit_transform(df['family_history_with_overweight'])
# Display the modified DataFrame
df.head()
#1 for yes and 0 for no
# Out:
#    Gender   Age  Height  Weight  family_history_with_overweight FAVC  FCVC  \
# 0       0  21.0    1.62    64.0                               1   no   2.0
# 1       0  21.0    1.52    56.0                               1   no   3.0
# 2       1  23.0    1.80    77.0                               1   no   2.0
# 3       1  27.0    1.80    87.0                               0   no   3.0
# 4       1  22.0    1.78    89.8                               0   no   2.0
#
#    NCP       CAEC SMOKE  CH2O  SCC  FAF  TUE        CALC  \
# 0  3.0  Sometimes    no   2.0   no  0.0  1.0          no
# 1  3.0  Sometimes   yes   3.0  yes  3.0  0.0   Sometimes
# 2  3.0  Sometimes    no   2.0   no  2.0  1.0  Frequently
# 3  3.0  Sometimes    no   2.0   no  2.0  0.0  Frequently
# 4  1.0  Sometimes    no   2.0   no  0.0  0.0   Sometimes
#
#                   MTRANS           NObeyesdad
# 0  Public_Transportation        Normal_Weight
# 1  Public_Transportation        Normal_Weight
# ...

# %%
df['FAVC'] = df['FAVC'].map({'no':0, 'yes':1})

# %%
df.tail()
# Out:
#       Gender   Age    Height      Weight  family_history_with_overweight  \
# 2106       0  21.0  1.710730  131.408528                               1
# 2107       0  22.0  1.748584  133.742943                               1
# 2108       0  23.0  1.752206  133.689352                               1
# 2109       0  24.0  1.739450  133.346641                               1
# 2110       0  24.0  1.738836  133.472641                               1
#
#       FAVC  FCVC  NCP       CAEC SMOKE      CH2O SCC       FAF       TUE  \
# 2106     1   3.0  3.0  Sometimes    no  1.728139  no  1.676269  0.906247
# 2107     1   3.0  3.0  Sometimes    no  2.005130  no  1.341390  0.599270
# 2108     1   3.0  3.0  Sometimes    no  2.054193  no  1.414209  0.646288
# 2109     1   3.0  3.0  Sometimes    no  2.852339  no  1.139107  0.586035
# 2110     1   3.0  3.0  Sometimes    no  2.863513  no  1.026452  0.714137
#
#            CALC                 MTRANS        NObeyesdad
# ...

# %%
df['FAVC'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df['CAEC'].unique()
# Out:
# array(['Sometimes', 'Frequently', 'Always', 'no'], dtype=object)

# %%
df['CAEC'] = df['CAEC'].map({'no':0, 'Sometimes':1, 'Frequently':2, 'Always':3})
df['SMOKE'] = df['SMOKE'].map({'no':0, 'yes':1})
df['SCC'] = df['SCC'].map({'no':0, 'yes':1})
df['CALC'] = df['CALC'].map({'no':0, 'Sometimes':1, 'Frequently':2, 'Always':3})

# %%
df['CAEC'].unique()
#sometimes:2,Frequenlty:1,'Always:0',no:3
# Out:
# array([1, 2, 3, 0], dtype=int64)

# %% [markdown]
# if we use label encoder Label encoding can introduce an implicit ordinal relationship between the categories, even when no such relationship exists in the original data. This can mislead the model into interpreting the data with a false sense of order.
#
# One major disadvantage of Label encoder is that it will compare that categories![image.png](attachment:image.png)

# %%
df
# Out:
#       Gender   Age    Height      Weight  family_history_with_overweight  \
# 0          0  21.0  1.620000   64.000000                               1
# 1          0  21.0  1.520000   56.000000                               1
# 2          1  23.0  1.800000   77.000000                               1
# 3          1  27.0  1.800000   87.000000                               0
# 4          1  22.0  1.780000   89.800000                               0
# ...      ...   ...       ...         ...                             ...
# 2106       0  21.0  1.710730  131.408528                               1
# 2107       0  22.0  1.748584  133.742943                               1
# 2108       0  23.0  1.752206  133.689352                               1
# 2109       0  24.0  1.739450  133.346641                               1
# 2110       0  24.0  1.738836  133.472641                               1
#
#       FAVC  FCVC  NCP  CAEC  SMOKE      CH2O  SCC       FAF       TUE  CALC  \
# ...

# %%
label_encoder=LabelEncoder()
# Fit and transform the 'Gender' column
df['MTRANS']=label_encoder.fit_transform(df['MTRANS'])
# Display the modified DataFrame
df.head()
# Out:
#    Gender   Age  Height  Weight  family_history_with_overweight  FAVC  FCVC  \
# 0       0  21.0    1.62    64.0                               1     0   2.0
# 1       0  21.0    1.52    56.0                               1     0   3.0
# 2       1  23.0    1.80    77.0                               1     0   2.0
# 3       1  27.0    1.80    87.0                               0     0   3.0
# 4       1  22.0    1.78    89.8                               0     0   2.0
#
#    NCP  CAEC  SMOKE  CH2O  SCC  FAF  TUE  CALC  MTRANS           NObeyesdad
# 0  3.0     1      0   2.0    0  0.0  1.0     0       3        Normal_Weight
# 1  3.0     1      1   3.0    1  3.0  0.0     1       3        Normal_Weight
# 2  3.0     1      0   2.0    0  2.0  1.0     2       3        Normal_Weight
# 3  3.0     1      0   2.0    0  2.0  0.0     2       4   Overweight_Level_I
# 4  1.0     1      0   2.0    0  0.0  0.0     1       3  Overweight_Level_II

# %%
df['MTRANS'].unique()
# Out:
# array([3, 4, 0, 2, 1])

# %%
df['NObeyesdad']=df['NObeyesdad'].map({'Insufficient_Weight':0,'Normal_Weight':1,'Overweight_Level_I'
                                       :2,'Overweight_Level_II':3,'Obesity_Type_I':4,'Obesity_Type_II':5,'Obesity_Type_III':6})

# %%
df
# Out:
#       Gender   Age    Height      Weight  family_history_with_overweight  \
# 0          0  21.0  1.620000   64.000000                               1
# 1          0  21.0  1.520000   56.000000                               1
# 2          1  23.0  1.800000   77.000000                               1
# 3          1  27.0  1.800000   87.000000                               0
# 4          1  22.0  1.780000   89.800000                               0
# ...      ...   ...       ...         ...                             ...
# 2106       0  21.0  1.710730  131.408528                               1
# 2107       0  22.0  1.748584  133.742943                               1
# 2108       0  23.0  1.752206  133.689352                               1
# 2109       0  24.0  1.739450  133.346641                               1
# 2110       0  24.0  1.738836  133.472641                               1
#
#       FAVC  FCVC  NCP  CAEC  SMOKE      CH2O  SCC       FAF       TUE  CALC  \
# ...

# %%
# Creating histograms for all features
df.hist(figsize=(12, 10), bins=20)
plt.suptitle('Histograms for all Features', fontsize=16)
plt.show()

# %%
import pylab
import scipy.stats as stat
def plot_data(df,feature):
    plt.figure(figsize=(10,6))
    plt.subplot(1,2,1)
    df[feature].hist()
    plt.subplot(1,2,2)
    stat.probplot(df[feature],dist='norm',plot=pylab)
    plt.show()
    
#plt.subplot(1,2,1)
#The first argument, 1, indicates the total number of rows in the grid.
#The second argument, 2, indicates the total number of columns in the grid.
#The third argument, 2, indicates the position of the subplot within the grid.
#In this case, plt.subplot(1, 2, 2) creates the second subplot in a 1x2 grid. 
#This means that there are two subplots in total, arranged horizontally. 
#The subplot is positioned at the second place in the grid.


#By setting plot=pylab, you're instructing the function to use the plotting capabilities provided by the pylab module, 
#which is a convenient and straightforward way to visualize the probability plot.

# %%
plot_data(df,'Age')

# %%
##### Square Root Transformation
df['Age_sqaure']=df.Age**(1/2)
plot_data(df,'Age_sqaure')

# %%
df['Age_Boxcox'],parameters=stat.boxcox(df['Age'])

# %%
plot_data(df,'Age_Boxcox')

# %%
plot_data(df,'Height')

# %%
##### Square Root Transformation
df['Height_sqaure']=df.Height**(1/2)
plot_data(df,'Height_sqaure')

# %%
df['Height_Boxcox'],parameters=stat.boxcox(df['Height'])

# %%
plot_data(df,'Height_Boxcox')

# %%
plot_data(df,'Weight')

# %%
##### Square Root Transformation
df['Weight_sqaure']=df.Weight**(1/2)
plot_data(df,'Weight_sqaure')

# %%
df['Weight_Boxcox'],parameters=stat.boxcox(df['Weight'])

# %%
plot_data(df,'Weight_Boxcox')

# %%
X=df.drop('NObeyesdad',axis=1)
y=df['NObeyesdad']

# %%
from lightgbm import LGBMClassifier
model_lgb = LGBMClassifier()
model_lgb.fit(X, y)

importances = model_lgb.feature_importances_
indices = np.argsort(importances)[::-1]

top_features = X.columns[indices][:22]
top_features_list = top_features.tolist()

plt.figure(figsize=(10, 8))
sns.barplot(y=X.columns[indices], x=importances[indices], orient='h')
plt.xlabel('Feature Importance')
plt.ylabel('Features')
plt.title('LightGBM Feature Importance')
plt.show()
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001066 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2891
# [LightGBM] [Info] Number of data points in the train set: 1926, number of used features: 22
# [LightGBM] [Info] Start training from score -1.979704
# [LightGBM] [Info] Start training from score -1.946429
# [LightGBM] [Info] Start training from score -2.014125
# [LightGBM] [Info] Start training from score -2.025866
# [LightGBM] [Info] Start training from score -1.921294
# [LightGBM] [Info] Start training from score -1.972214
# [LightGBM] [Info] Start training from score -1.782457
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %%
#df.drop('SMOKE',axis=1,inplace=True)
#df.drop('Weight_Boxcox',axis=1,inplace=True)
#df.drop('Weight_sqaure',axis=1,inplace=True)
#df.drop('Height_Boxcox',axis=1,inplace=True)
#df.drop('Height_sqaure',axis=1,inplace=True)
#df.drop('Age_Boxcox',axis=1,inplace=True)
#df.drop('Age_sqaure',axis=1,inplace=True)

# %%
df
# Out:
#       Gender   Age    Height      Weight  family_history_with_overweight  \
# 0          0  21.0  1.620000   64.000000                               1
# 1          0  21.0  1.520000   56.000000                               1
# 2          1  23.0  1.800000   77.000000                               1
# 3          1  27.0  1.800000   87.000000                               0
# 4          1  22.0  1.780000   89.800000                               0
# ...      ...   ...       ...         ...                             ...
# 2106       0  21.0  1.710730  131.408528                               1
# 2107       0  22.0  1.748584  133.742943                               1
# 2108       0  23.0  1.752206  133.689352                               1
# 2109       0  24.0  1.739450  133.346641                               1
# 2110       0  24.0  1.738836  133.472641                               1
#
#       FAVC  FCVC  NCP  CAEC  SMOKE      CH2O  SCC       FAF       TUE  CALC  \
# ...

# %%
X.drop('SMOKE',axis=1,inplace=True)
X.drop('Weight_Boxcox',axis=1,inplace=True)
X.drop('Weight_sqaure',axis=1,inplace=True)
X.drop('Height_Boxcox',axis=1,inplace=True)
X.drop('Height_sqaure',axis=1,inplace=True)
X.drop('Age_Boxcox',axis=1,inplace=True)
X.drop('Age_sqaure',axis=1,inplace=True)

# %%
from sklearn.preprocessing import StandardScaler

# Initialize the StandardScaler
scaler = StandardScaler()
# Numerical columns
num_cols = [col for col in X.columns if X[col].dtype != 'object']
# Make a copy of the DataFrame to avoid modifying the original data
df1 = X.copy()

# Learn the statistical parameters for each numerical column and transform the data
df1[num_cols] = scaler.fit_transform(df1[num_cols])

# Display the first few rows of the scaled DataFrame
df1.head()
# Out:
#      Gender       Age    Height    Weight  family_history_with_overweight  \
# 0 -1.025241 -0.460895 -0.937422 -0.854276                        0.472900
# 1 -1.025241 -0.460895 -2.024897 -1.152561                        0.472900
# 2  0.975381 -0.005906  1.020032 -0.369564                        0.472900
# 3  0.975381  0.904072  1.020032  0.003291                       -2.114614
# 4  0.975381 -0.233400  0.802537  0.107691                       -2.114614
#
#        FAVC      FCVC       NCP      CAEC      CH2O       SCC       FAF  \
# 0 -2.728987 -0.786661  0.380511 -0.320542 -0.024094 -0.226517 -1.210367
# 1 -2.728987  1.048905  0.380511 -0.320542  1.624614  4.414676  2.323007
# 2 -2.728987 -0.786661  0.380511 -0.320542 -0.024094 -0.226517  1.145216
# 3 -2.728987  1.048905  0.380511 -0.320542 -0.024094 -0.226517  1.145216
# 4 -2.728987 -0.786661 -2.238884 -0.320542 -0.024094 -0.226517 -1.210367
#
#         TUE      CALC    MTRANS
# 0  0.491422 -1.434515  0.410440
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
 
# initialising the MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))
 
# Numerical columns
num_col_ = [col for col in df.columns if df[col].dtype != 'object']
df2 = df
# learning the statistical parameters for each of the data and transforming
df2[num_col_] = scaler.fit_transform(df[num_col_])
df2.tail()
# Out:
#       Gender       Age    Height    Weight  family_history_with_overweight  \
# 2106     0.0  0.333333  0.496002  0.689616                             1.0
# 2107     0.0  0.380952  0.568014  0.707037                             1.0
# 2108     0.0  0.428571  0.574904  0.706637                             1.0
# 2109     0.0  0.476190  0.550638  0.704079                             1.0
# 2110     0.0  0.476190  0.549470  0.705020                             1.0
#
#       FAVC  FCVC       NCP      CAEC  SMOKE      CH2O  SCC       FAF  \
# 2106   1.0   1.0  0.666667  0.333333    0.0  0.364070  0.0  0.558756
# 2107   1.0   1.0  0.666667  0.333333    0.0  0.502565  0.0  0.447130
# 2108   1.0   1.0  0.666667  0.333333    0.0  0.527097  0.0  0.471403
# 2109   1.0   1.0  0.666667  0.333333    0.0  0.926170  0.0  0.379702
# 2110   1.0   1.0  0.666667  0.333333    0.0  0.931757  0.0  0.342151
#
#            TUE      CALC  MTRANS  NObeyesdad  Age_sqaure  Age_Boxcox  \
# ...

# %%
df1.describe()
# Out:
#              Gender           Age        Height        Weight  \
# count  1.926000e+03  1.926000e+03  1.926000e+03  1.926000e+03
# mean   2.483072e-15  2.002840e-16  1.190291e-15 -1.419425e-15
# std    1.000260e+00  1.000260e+00  1.000260e+00  1.000260e+00
# min   -1.025241e+00 -2.053356e+00 -2.786129e+00 -1.786415e+00
# 25%   -1.025241e+00 -6.883893e-01 -7.713348e-01 -8.169909e-01
# 50%    9.753808e-01 -2.334004e-01 -2.168139e-02 -1.085654e-01
# 75%    9.753808e-01  6.765776e-01  7.156754e-01  8.120930e-01
# max    9.753808e-01  2.724028e+00  2.930323e+00  3.209848e+00
#
#        family_history_with_overweight          FAVC          FCVC  \
# count                    1.926000e+03  1.926000e+03  1.926000e+03
# mean                     1.094515e-14  6.460795e-15 -1.731625e-16
# std                      1.000260e+00  1.000260e+00  1.000260e+00
# min                     -2.114614e+00 -2.728987e+00 -2.622227e+00
# 25%                      4.728996e-01  3.664364e-01 -7.866612e-01
# ...
